# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "https://ergast.com/api/f1/2020/1/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'abilities': [{'ability': {'name': 'overgrow',
#     'url': 'https://pokeapi.co/api/v2/ability/65/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'chlorophyll',
#     'url': 'https://pokeapi.co/api/v2/ability/34/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 64,
#  'forms': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}],
#  'game_indices': [{'game_index': 153,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 153,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 153,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 1,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 1,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 1,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
print(data)
# Out:
# [{'position': '1', 'positionText': '1', 'points': '25', 'wins': '1', 'Driver': {'driverId': 'bottas', 'permanentNumber': '77', 'code': 'BOT', 'url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas', 'givenName': 'Valtteri', 'familyName': 'Bottas', 'dateOfBirth': '1989-08-28', 'nationality': 'Finnish'}, 'Constructors': [{'constructorId': 'mercedes', 'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One', 'name': 'Mercedes', 'nationality': 'German'}]}, {'position': '2', 'positionText': '2', 'points': '18', 'wins': '0', 'Driver': {'driverId': 'leclerc', 'permanentNumber': '16', 'code': 'LEC', 'url': 'http://en.wikipedia.org/wiki/Charles_Leclerc', 'givenName': 'Charles', 'familyName': 'Leclerc', 'dateOfBirth': '1997-10-16', 'nationality': 'Monegasque'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}, {'position': '3', 'positionText': '3', 'points': '16', 'wins': '0', 'Driver': 
# ...

# %%
def racer_data(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        racer_dict[racer_name] ={
            "first_name": racer['Driver']['givenName'],
            "last_name":racer['Driver']['familyName'],
            "positions": racer['position'],
            "wins": racer["wins"],
            "DOB":racer['Driver']['dateOfBirth'],
            "nationality":racer['Driver']['nationality'],
            "constructor": racer["Constructors"][0]["name"]
        }
        new_data.append(racer_dict)
    return new_data

print(racer_data(data))
# Out:
# [{'Valtteri Bottas': {'first_name': 'Valtteri', 'last_name': 'Bottas', 'positions': '1', 'wins': '1', 'DOB': '1989-08-28', 'nationality': 'Finnish', 'constructor': 'Mercedes'}}, {'Charles Leclerc': {'first_name': 'Charles', 'last_name': 'Leclerc', 'positions': '2', 'wins': '0', 'DOB': '1997-10-16', 'nationality': 'Monegasque', 'constructor': 'Ferrari'}}, {'Lando Norris': {'first_name': 'Lando', 'last_name': 'Norris', 'positions': '3', 'wins': '0', 'DOB': '1999-11-13', 'nationality': 'British', 'constructor': 'McLaren'}}, {'Lewis Hamilton': {'first_name': 'Lewis', 'last_name': 'Hamilton', 'positions': '4', 'wins': '0', 'DOB': '1985-01-07', 'nationality': 'British', 'constructor': 'Mercedes'}}, {'Carlos Sainz': {'first_name': 'Carlos', 'last_name': 'Sainz', 'positions': '5', 'wins': '0', 'DOB': '1994-09-01', 'nationality': 'Spanish', 'constructor': 'McLaren'}}, {'Sergio Pérez': {'first_name': 'Sergio', 'last_name': 'Pérez', 'positions': '6', 'wins': '0', 'DOB': '1990-01-26', 'nationali
# ...

# %%
def get_driver_info_by_yr_and_round(year, r):
    url = f"https://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]:
        return "We had error"
    else:
        data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
        return racer_data(data)
get_driver_info_by_yr_and_round(2020,3)[0:5]
# Out:
# [{'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'positions': '1',
#    'wins': '2',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'positions': '2',
#    'wins': '1',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'constructor': 'Mercedes'}},
#  {'Max Verstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'positions': '3',
#    'wins': '0',
#    'DOB': '1997-09-30',
#    'nationality': 'Dutch',
#    'constructor': 'Red Bull'}},
#  {'Lando Norris': {'first_name': 'Lando',
#    'last_name': 'Norris',
#    'positions': '4',
#    'wins': '0',
#    'DOB': '1999-11-13',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'Alexander Albon': {'first_name': 'Alexander',
#    'last_name': 'Albon',
#    'positions': '5',
#    'wins': '0',
#    'DOB': '1996-03-23',
#    'nationality': 'Thai',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
url = "https://pokeapi.co/api/v2/pokemon/bulbasaur"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response.ok
# Out:
# True

# %%
data = response.json()
print(data)
# Out:
# {'abilities': [{'ability': {'name': 'overgrow', 'url': 'https://pokeapi.co/api/v2/ability/65/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'chlorophyll', 'url': 'https://pokeapi.co/api/v2/ability/34/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 64, 'forms': [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}], 'game_indices': [{'game_index': 153, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 153, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 153, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 1, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 1, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 1, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 1, 'version': {'name': 'ruby'
# ...

# %%
def get_pokemon_data(data):
    new_data=[]
    poki_dict={}
    poki_name = data["name"]
    poki_dict[poki_name] = {
        "ability":data['abilities'][0]['ability']['name'],
        "base_experience": data['base_experience'],
        "sprite_url": data['sprites']['front_shiny']
    }
    new_data.append(poki_dict)
    return new_data

# %%
def get_pokemon(pokemon_name):
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon_name}"
    response = requests.get(url)
    if response.ok:
        data = response.json()
        return get_pokemon_data(data)
    else:
        return "We could not find a pokemon with this name, please try again."

# %%
get_pokemon('mew')
# Out:
# [{'mew': {'ability': 'synchronize',
#    'base_experience': 270,
#    'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png'}}]

# %%
get_pokemon('bulbasaur')
# Out:
# [{'bulbasaur': {'ability': 'overgrow',
#    'base_experience': 64,
#    'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png'}}]

# %%
get_pokemon('swatch')
# Out:
# 'We could not find a pokemon with this name, please try again.'

# %%
get_pokemon('pikachu')
# Out:
# [{'pikachu': {'ability': 'static',
#    'base_experience': 112,
#    'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/25.png'}}]

# %%
get_pokemon('eevee')
# Out:
# [{'eevee': {'ability': 'run-away',
#    'base_experience': 65,
#    'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/133.png'}}]

# %%
get_pokemon('squirtle')
# Out:
# [{'squirtle': {'ability': 'torrent',
#    'base_experience': 63,
#    'sprite_url': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/7.png'}}]
